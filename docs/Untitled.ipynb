# %%
# %matplotlib inline
import sys
sys.path.append("/Users/yasunobu/Documents/src/EMPeaks_1.0.0")
from EMPeaks import GaussianMixture

# %%
# %matplotlib inline
from EMPeaks import GaussianMixture
import numpy as np
import matplotlib.pyplot as plt

lum = np.arange(256)
y=np.exp(-(lum-100)**2/100)
plt.plot(lum, y)
dat2d = np.append(lum, y, axis=0).reshape(2,256)
print(dat2d)
adapted_em = GaussianMixture.SpectrumAdaptedEM(dat2d, K=1)
adapted_em.gmm_mu_ = [70]
# %time adapted_em.fit()
fig = adapted_em.plot_fitting_summary(75, save=True)
# Out:
# [[0.00000000e+000 1.00000000e+000 2.00000000e+000 3.00000000e+000
#   4.00000000e+000 5.00000000e+000 6.00000000e+000 7.00000000e+000
#   8.00000000e+000 9.00000000e+000 1.00000000e+001 1.10000000e+001
#   1.20000000e+001 1.30000000e+001 1.40000000e+001 1.50000000e+001
#   1.60000000e+001 1.70000000e+001 1.80000000e+001 1.90000000e+001
#   2.00000000e+001 2.10000000e+001 2.20000000e+001 2.30000000e+001
#   2.40000000e+001 2.50000000e+001 2.60000000e+001 2.70000000e+001
#   2.80000000e+001 2.90000000e+001 3.00000000e+001 3.10000000e+001
#   3.20000000e+001 3.30000000e+001 3.40000000e+001 3.50000000e+001
#   3.60000000e+001 3.70000000e+001 3.80000000e+001 3.90000000e+001
#   4.00000000e+001 4.10000000e+001 4.20000000e+001 4.30000000e+001
#   4.40000000e+001 4.50000000e+001 4.60000000e+001 4.70000000e+001
#   4.80000000e+001 4.90000000e+001 5.00000000e+001 5.10000000e+001
#   5.20000000e+001 5.30000000e+001 5.40000000e+001 5.50000000e+001
# ...
